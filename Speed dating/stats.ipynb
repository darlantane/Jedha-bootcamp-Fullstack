# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Speed+Dating+Data.csv', encoding='cp1252')
data.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 4      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
#
#    fun5_3  amb5_3
# 0     NaN     NaN
# ...

# %%
data.columns
# Out:
# Index(['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round', 'position',
#        'positin1', 'order',
#        ...
#        'attr3_3', 'sinc3_3', 'intel3_3', 'fun3_3', 'amb3_3', 'attr5_3',
#        'sinc5_3', 'intel5_3', 'fun5_3', 'amb5_3'],
#       dtype='object', length=195)

# %%
ds=data[['gender','age','race','imprace','imprelig']]
ds.head()
# Out:
#    gender   age  race  imprace  imprelig
# 0       0  21.0   4.0      2.0       4.0
# 1       0  21.0   4.0      2.0       4.0
# 2       0  21.0   4.0      2.0       4.0
# 3       0  21.0   4.0      2.0       4.0
# 4       0  21.0   4.0      2.0       4.0

# %%
race_labels = {1.0 : 'Black/African American',
	2.0 : 'European/Caucasian-American',
	3.0 : 'Latino/Hispanic American',
	4.0 : 'Asian/Pacific Islander/Asian-American',
	5.0 : 'Native American=5',
	6.0 : 'Other'
}

gender_labels = {0 : 'Female', 1 : 'Male'}

ds['race'] = ds['race'].replace(race_labels)
ds['gender']= ds['gender'].replace(gender_labels)
# Out:
# C:\Users\darla\AppData\Local\Temp\ipykernel_21912\3286736516.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds['race'] = ds['race'].replace(race_labels)
# C:\Users\darla\AppData\Local\Temp\ipykernel_21912\3286736516.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds['gender']= ds['gender'].replace(gender_labels)

# %%
plt.figure(figsize=(7, 7))
plt.xticks(rotation='vertical')
plt.title("Importance de la race selon la race et le genre")

sns.barplot(ds, x='race', y='imprace', hue='gender', errorbar=None, palette='rocket')
# Out:
# <Axes: title={'center': 'Importance de la race selon la race et le genre'}, xlabel='race', ylabel='imprace'>

# %%
plt.figure(figsize=(15, 6))
plt.title('Importance de la race selon l_age')
sns.barplot(ds, x='age', y='imprace', hue='gender', errorbar=None, palette='pastel')
# Out:
# <Axes: title={'center': 'Importance de la race selon l_age'}, xlabel='age', ylabel='imprace'>

# %%
plt.figure(figsize=(7, 7))
plt.xticks(rotation='vertical')
plt.title("Importance de la religion selon la race et le genre")

sns.barplot(ds, x='race', y='imprelig', hue='gender', errorbar=None, palette='rocket')
# Out:
# <Axes: title={'center': 'Importance de la religion selon la race et le genre'}, xlabel='race', ylabel='imprelig'>

# %%
plt.figure(figsize=(15, 6))
plt.title('Importance de la religion selon l_age')
sns.barplot(ds, x='age', y='imprelig', hue='gender', errorbar=None, palette='pastel')
# Out:
# <Axes: title={'center': 'Importance de la religion selon l_age'}, xlabel='age', ylabel='imprelig'>

# %%
dt = data[['gender','age','race','match','sports','tvsports','exercise','dining','museums','art','hiking','gaming','clubbing','reading','tv','theater','movies','concerts','music','shopping','yoga']]
dt
# Out:
#       gender   age  race  match  sports  tvsports  exercise  dining  museums  \
# 0          0  21.0   4.0      0     9.0       2.0       8.0     9.0      1.0
# 1          0  21.0   4.0      0     9.0       2.0       8.0     9.0      1.0
# 2          0  21.0   4.0      1     9.0       2.0       8.0     9.0      1.0
# 3          0  21.0   4.0      1     9.0       2.0       8.0     9.0      1.0
# 4          0  21.0   4.0      1     9.0       2.0       8.0     9.0      1.0
# ...      ...   ...   ...    ...     ...       ...       ...     ...      ...
# 8373       1  25.0   2.0      0     8.0       2.0       5.0    10.0     10.0
# 8374       1  25.0   2.0      0     8.0       2.0       5.0    10.0     10.0
# 8375       1  25.0   2.0      0     8.0       2.0       5.0    10.0     10.0
# 8376       1  25.0   2.0      0     8.0       2.0       5.0    10.0     10.0
# 8377       1  25.0   2.0      0     8.0       2.0       5.0    10.0     10.0
#
# ...

# %%
lower_bound = dt.quantile(0.01)
upper_bound = dt.quantile(0.99)
dt = dt[(dt >= lower_bound) & (dt <= upper_bound)]

dt['race'] = dt['race'].replace(race_labels)
dt['gender']= dt['gender'].replace(gender_labels)

# %%
plt.figure(figsize=(5, 5))
plt.xticks(rotation='vertical')
plt.title("Taux de match des fans de sport")

sns.barplot(dt, x='tvsports', y='match', hue='gender', errorbar=None, palette='rocket')
# Out:
# <Axes: title={'center': 'Taux de match des fans de sport'}, xlabel='tvsports', ylabel='match'>

# %%
plt.figure(figsize=(5, 5))
plt.xticks(rotation='vertical')
plt.title("Taux de match des sportifs")

sns.barplot(dt, x='sports', y='match', hue='gender', errorbar=None, palette='rocket')
# Out:
# <Axes: title={'center': 'Taux de match des sportifs'}, xlabel='sports', ylabel='match'>

# %%
plt.figure(figsize=(5, 5))
plt.xticks(rotation='vertical')
plt.title("Taux de match des cinéphiles")

sns.barplot(dt, x='movies', y='match', hue='gender', errorbar=None, palette='rocket')
# Out:
# <Axes: title={'center': 'Taux de match des cinéphiles'}, xlabel='movies', ylabel='match'>

# %%
plt.figure(figsize=(5, 5))
plt.xticks(rotation='vertical')
plt.title("Taux de match des artistes")

sns.barplot(dt, x='art', y='match', hue='gender', errorbar=None, palette='rocket')
# Out:
# <Axes: title={'center': 'Taux de match des artistes'}, xlabel='art', ylabel='match'>

# %%
plt.figure(figsize=(5, 5))
plt.xticks(rotation='vertical')
plt.title("Taux de match des gamers")

sns.barplot(dt, x='gaming', y='match', hue='gender', errorbar=None, palette='rocket')
# Out:
# <Axes: title={'center': 'Taux de match des gamers'}, xlabel='gaming', ylabel='match'>

# %%
plt.figure(figsize=(5, 5))
plt.xticks(rotation='vertical')
plt.title("Taux de match des clubers")

sns.barplot(dt, x='clubbing', y='match', hue='gender', errorbar=None, palette='rocket')
# Out:
# <Axes: title={'center': 'Taux de match des clubers'}, xlabel='clubbing', ylabel='match'>

# %%
plt.figure(figsize=(5, 5))
plt.xticks(rotation='vertical')
plt.title("Taux de match des fans de concerts")

sns.barplot(dt, x='concerts', y='match', hue='gender', errorbar=None, palette='rocket')
# Out:
# <Axes: title={'center': 'Taux de match des fans de concerts'}, xlabel='concerts', ylabel='match'>

# %%
plt.figure(figsize=(5, 5))
plt.xticks(rotation='vertical')
plt.title("Taux de match des musiciens")

sns.barplot(dt, x='music', y='match', hue='gender', errorbar=None, palette='rocket')
# Out:
# <Axes: title={'center': 'Taux de match des musiciens'}, xlabel='music', ylabel='match'>

# %%
plt.figure(figsize=(5, 5))
plt.xticks(rotation='vertical')
plt.title("Taux de match des fans de shopping")

sns.barplot(dt, x='shopping', y='match', hue='gender', errorbar=None, palette='rocket')

plt.show()

# %%
plt.figure(figsize=(5, 5))
plt.xticks(rotation='vertical')
plt.title("Taux de match des maitres yoga")

sns.barplot(dt, x='yoga', y='match', hue='gender', errorbar=None, palette='rocket')
# Out:
# <Axes: title={'center': 'Taux de match des maitres yoga'}, xlabel='yoga', ylabel='match'>

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

sns.barplot(dt, x='yoga', y='match', hue='gender', errorbar=None, palette='rocket')
axes[0, 0].set_title("Taux de match des maitres yoga")

sns.barplot(dt, x='shopping', y='match', hue='gender', errorbar=None, palette='rocket')
axes[0, 1].set_title("Taux de match des fans de shopping")

sns.barplot(dt, x='music', y='match', hue='gender', errorbar=None, palette='rocket')
axes[1, 0].set_title("Taux de match des musiciens")

sns.barplot(dt, x='concerts', y='match', hue='gender', errorbar=None, palette='rocket')
axes[1, 1].set_title("Taux de match des fans de concerts")


plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[300], line 16
#      13 axes[1, 1].set_title("Taux de match des fans de concerts")
#      15 sns.barplot(dt, x='clubbing', y='match', hue='gender', errorbar=None, palette='rocket')
# ---> 16 axes[1, 2].set_title("Taux de match des clubers")
#      18 sns.barplot(dt, x='gaming', y='match', hue='gender', errorbar=None, palette='rocket')
#      19 axes[1, 1, 0, 0].set_title("Taux de match des gamers")
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

sns.barplot(dt, x='clubbing', y='match', hue='gender', errorbar=None, palette='rocket')
axes[0, 0].set_title("Taux de match des clubers")

sns.barplot(dt, x='gaming', y='match', hue='gender', errorbar=None, palette='rocket')
axes[0, 1].set_title("Taux de match des gamers")

sns.barplot(dt, x='art', y='match', hue='gender', errorbar=None, palette='rocket')
axes[1, 0].set_title("Taux de match des artistes")

sns.barplot(dt, x='movies', y='match', hue='gender', errorbar=None, palette='rocket')
axes[1, 1].set_title("Taux de match des cinéphiles")

plt.show()

# %%
sns.barplot(dt, x='sports', y='match', hue='gender', errorbar=None, palette='rocket')
axes[0, 0].set_title("Taux de match des sportifs")

sns.barplot(dt, x='tvsports', y='match', hue='gender', errorbar=None, palette='rocket')
axes[0, 1].set_title("Taux de match des fans de sport")

plt.show()
