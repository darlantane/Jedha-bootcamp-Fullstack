# %%
import seaborn as sns
import pandas as pd

# %%
dataset = pd.read_csv("sales_predictions.csv")

# %%
dataset.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
dataset = dataset.sample(25)
dataset.head()
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2512708  08.03.2015              26       49    20653      1899.0
# 380734   01.04.2013               3       22      687       600.0
# 1351727  19.01.2014              12       25    15063       449.0
# 1407117  11.02.2014              13       22    16286       149.0
# 2014140  10.09.2014              20       12    12231       350.0
#
#          item_cnt_day
# 2512708           1.0
# 380734            1.0
# 1351727           1.0
# 1407117           1.0
# 2014140           1.0

# %%
sns.relplot(x="date", y="item_price", data = dataset, kind="line", height = 5, aspect = 5)

# %%
sns.relplot(x="date", y="item_price", data = dataset, kind="line", height = 5, aspect = 5)
